# %% [markdown]
# # Create Tenforflow dataset using Pascal VOC Folder Structure

# %%
import os
import numpy as np
import xml.etree.ElementTree as ET
from collections import OrderedDict
import matplotlib.pyplot as plt
import pandas as pd
import glob
import io
from collections import namedtuple
from PIL import Image
import tensorflow as tf

# %%
def extract_single_xml_file(tree):
    Nobj = 0
    row  = OrderedDict()
    labels = {'basantapur tower': 1, 'bhimeleshvara': 2, 'gaddi baithak': 3, 'garud': 4, 'kasthamandap': 5, 'lalitpur tower': 6, 'trailokya mohan': 7}
    for elems in tree.iter():
        if elems.tag == "size":
            for elem in elems:
                row[elem.tag] = int(elem.text)
        if elems.tag == "object":
            for elem in elems:
                if elem.tag == "name":
                    row["bbx_{}_{}".format(Nobj,elem.tag)] = str(elem.text)
                    row["bbx_{}_{}".format(Nobj, 'labelID')] = int(labels[str(elem.text)])
                if elem.tag == "bndbox":
                    for k in elem:
                        row["bbx_{}_{}".format(Nobj,k.tag)] = float(k.text)
                    Nobj += 1
    row["Nobj"] = Nobj
    return(row)

# %%
def xml_to_df(path):
    df_anno = []
    dir_anno = path + "/Annotations"
    for fnm in os.listdir(dir_anno):  
        if not fnm.startswith('.') and not fnm == 'desktop.ini': ## do not include hidden folders/files
            tree = ET.parse(os.path.join(dir_anno,fnm))
            row = extract_single_xml_file(tree)
            row["fileID"] = fnm.split(".")[0]
            df_anno.append(row)
    df_anno = pd.DataFrame(df_anno)
    maxNobj = np.max(df_anno["Nobj"])
    return df_anno

# %%
def dataset_dictionary_creator(path):
    base_image_dir = path + '/JPEGImages/'
    df_anno = xml_to_df(path)
    print(df_anno.shape)
    total_rows = df_anno.shape[0]
    dataset = []
    for row in range(total_rows):
        data_dict = {}
        image_filename = df_anno.iloc[row]['fileID'] + '.JPG'

        im = Image.open(base_image_dir + image_filename)
        data_dict['image'] = tf.convert_to_tensor(im)

        data_dict['image/filename'] = tf.constant(image_filename)
        no_objects = df_anno.iloc[row]['Nobj']

        temp_dict = {}
        prt_rw = df_anno.iloc[row]
        bboxes_list = []
        label_list = []
        for i in range(no_objects):
            # xmin, ymin, xmax, ymax
            bbox_cor = [prt_rw['bbx_'+ str(i) + '_xmin'] / 300, prt_rw['bbx_' + str(i) + '_ymin'] / 300, prt_rw['bbx_' + str(i) + '_xmax'] / 300, prt_rw['bbx_' + str(i) + '_ymax'] / 300]
            bboxes_list.append(bbox_cor)

            #label_list_ID
            label_list.append(int(prt_rw['bbx_'+str(i)+'_labelID']))
        data_dict['bboxes'] = tf.Variable(bboxes_list, dtype = 'float32')
        data_dict['labels'] = tf.Variable(label_list, dtype = 'int64')
        im.close()
        dataset.append(data_dict)
    return dataset

# %%
train_dataset = dataset_dictionary_creator('./Dataset/train')
test_dataset = dataset_dictionary_creator('./Dataset/test')
# Out:
# (506, 23)
# (173, 23)

# %%
import pickle
train_file = open('train_dataset', 'wb')
pickle.dump(train_dataset, train_file)
train_file.close()

test_file = open('test_dataset', 'wb')
pickle.dump(test_dataset, test_file)
test_file.close()

# %%
temp_file = open('train_dataset', 'rb')
train_dataset = pickle.load(temp_file)

# %%
train_dataset
# Out:
# [{'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[192, 129, 122],
#           [194, 134, 124],
#           [195, 137, 125],
#           ...,
#           [ 95, 157, 234],
#           [ 95, 157, 234],
#           [ 95, 157, 234]],
#
#          [[183, 118, 112],
#           [181, 118, 111],
#           [189, 129, 119],
#           ...,
#           [ 95, 157, 234],
#           [ 95, 157, 234],
#           [ 95, 157, 234]],
#
#          [[164,  97,  91],
#           [163,  98,  92],
#           [166, 106,  96],
#           ...,
#           [ 95, 157, 234],
#           [ 95, 157, 234],
#           [ 94, 156, 233]],
#
#          ...,
#
#          [[224, 127,  94],
#           [218, 134, 100],
#           [195, 122,  89],
#           ...,
#           [ 94, 155, 236],
#           [ 93, 154, 235],
#           [ 93, 154, 235]],
#
#          [[222, 125,  92],
#           [217, 133,  99],
#           [194, 121,  88],
#           ...,
#           [ 94, 155, 236],
#           [ 93, 154, 235],
#           [ 93, 154, 235]],
#
#          [[223, 126,  93],
#           [217, 131,  98],
#           [192, 119,  86],
#           ...,
#           [ 96, 154, 236],
#           [ 95, 153, 235],
#           [ 95, 153, 235]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (1).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.01      , 0.29666665, 0.9066667 , 0.99      ]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[ 53,  84, 149],
#           [ 43,  88, 155],
#           [ 24,  72, 134],
#           ...,
#           [ 79, 140, 220],
#           [ 79, 140, 220],
#           [ 79, 140, 220]],
#
#          [[ 47,  85, 148],
#           [ 38,  84, 144],
#           [ 24,  69, 124],
#           ...,
#           [ 79, 140, 220],
#           [ 78, 139, 219],
#           [ 78, 139, 219]],
#
#          [[ 43,  89, 151],
#           [ 37,  82, 139],
#           [ 20,  60, 112],
#           ...,
#           [ 78, 139, 219],
#           [ 78, 139, 219],
#           [ 78, 139, 219]],
#
#          ...,
#
#          [[ 67,  66,  74],
#           [ 53,  53,  63],
#           [ 44,  46,  58],
#           ...,
#           [ 76, 134, 216],
#           [ 76, 134, 216],
#           [ 76, 134, 216]],
#
#          [[ 57,  56,  64],
#           [ 60,  60,  70],
#           [ 50,  52,  64],
#           ...,
#           [ 76, 134, 216],
#           [ 76, 134, 216],
#           [ 76, 134, 216]],
#
#          [[ 41,  39,  50],
#           [ 64,  62,  73],
#           [ 55,  55,  67],
#           ...,
#           [ 76, 134, 216],
#           [ 76, 134, 216],
#           [ 76, 134, 216]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (10).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.17333333, 0.23      , 0.7966667 , 0.81333333]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[ 82, 149, 230],
#           [ 80, 148, 229],
#           [ 80, 148, 229],
#           ...,
#           [ 86, 154, 235],
#           [ 86, 154, 235],
#           [ 86, 154, 235]],
#
#          [[ 82, 149, 230],
#           [ 81, 149, 230],
#           [ 80, 148, 229],
#           ...,
#           [ 86, 154, 235],
#           [ 86, 154, 235],
#           [ 86, 154, 235]],
#
#          [[ 82, 149, 230],
#           [ 81, 149, 230],
#           [ 80, 148, 229],
#           ...,
#           [ 86, 154, 235],
#           [ 86, 154, 235],
#           [ 86, 154, 235]],
#
#          ...,
#
#          [[241, 243, 230],
#           [242, 244, 231],
#           [243, 243, 233],
#           ...,
#           [120, 115, 121],
#           [114, 109, 113],
#           [122, 117, 121]],
#
#          [[234, 235, 229],
#           [235, 236, 230],
#           [237, 236, 231],
#           ...,
#           [117, 114, 121],
#           [112, 109, 118],
#           [122, 121, 129]],
#
#          [[222, 222, 222],
#           [222, 222, 222],
#           [223, 221, 222],
#           ...,
#           [111, 111, 123],
#           [109, 109, 121],
#           [121, 121, 133]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (11).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.1       , 0.22666667, 0.47666666, 0.95666665]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[ 91, 160, 238],
#           [ 91, 160, 238],
#           [ 90, 159, 237],
#           ...,
#           [ 94, 161, 240],
#           [ 94, 161, 240],
#           [ 94, 161, 240]],
#
#          [[ 91, 160, 238],
#           [ 90, 159, 237],
#           [ 90, 159, 237],
#           ...,
#           [ 95, 162, 241],
#           [ 95, 162, 241],
#           [ 94, 161, 240]],
#
#          [[ 90, 159, 237],
#           [ 90, 159, 237],
#           [ 89, 158, 236],
#           ...,
#           [ 95, 162, 241],
#           [ 95, 162, 241],
#           [ 94, 161, 240]],
#
#          ...,
#
#          [[138,  99,  84],
#           [119,  90,  72],
#           [109,  86,  68],
#           ...,
#           [ 71,  77,  65],
#           [ 71,  75,  74],
#           [ 96,  91,  97]],
#
#          [[161, 119,  94],
#           [132, 100,  77],
#           [115,  92,  76],
#           ...,
#           [ 96,  93,  76],
#           [ 71,  66,  63],
#           [ 95,  84,  90]],
#
#          [[165, 122,  90],
#           [154, 125,  95],
#           [141, 121,  96],
#           ...,
#           [120, 105,  86],
#           [ 73,  53,  52],
#           [ 80,  59,  66]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (12).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.08666667, 0.00333333, 0.46333334, 0.83666664]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[145, 117,  95],
#           [125,  97,  75],
#           [137, 109,  87],
#           ...,
#           [ 80, 139, 219],
#           [ 80, 139, 219],
#           [ 80, 139, 219]],
#
#          [[133, 106,  89],
#           [125,  96,  80],
#           [136, 105,  87],
#           ...,
#           [ 80, 139, 219],
#           [ 79, 138, 218],
#           [ 79, 138, 218]],
#
#          [[110,  86,  76],
#           [110,  81,  73],
#           [120,  88,  77],
#           ...,
#           [ 80, 139, 219],
#           [ 79, 138, 218],
#           [ 79, 138, 218]],
#
#          ...,
#
#          [[ 26,  16,  25],
#           [ 27,  18,  23],
#           [ 53,  33,  32],
#           ...,
#           [ 80, 138, 220],
#           [ 80, 138, 220],
#           [ 80, 138, 220]],
#
#          [[ 31,  20,  16],
#           [ 33,  26,  20],
#           [ 52,  38,  35],
#           ...,
#           [ 81, 139, 221],
#           [ 81, 137, 222],
#           [ 81, 137, 222]],
#
#          [[ 37,  33,  24],
#           [ 53,  50,  41],
#           [ 59,  52,  46],
#           ...,
#           [ 82, 138, 223],
#           [ 82, 138, 223],
#           [ 81, 137, 222]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (13).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.15666667, 0.14666666, 0.78333336, 0.7366667 ]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[199, 177, 163],
#           [200, 181, 167],
#           [201, 185, 172],
#           ...,
#           [ 82, 144, 227],
#           [ 82, 144, 227],
#           [ 82, 144, 227]],
#
#          [[197, 178, 163],
#           [195, 178, 162],
#           [188, 174, 161],
#           ...,
#           [ 82, 144, 227],
#           [ 82, 144, 227],
#           [ 81, 143, 226]],
#
#          [[191, 172, 155],
#           [193, 177, 161],
#           [190, 178, 164],
#           ...,
#           [ 82, 144, 227],
#           [ 81, 143, 226],
#           [ 81, 143, 226]],
#
#          ...,
#
#          [[170, 125,  94],
#           [163, 113,  88],
#           [170, 109,  88],
#           ...,
#           [ 84, 144, 230],
#           [ 83, 143, 229],
#           [ 83, 143, 229]],
#
#          [[162, 123,  92],
#           [157, 111,  85],
#           [161, 106,  85],
#           ...,
#           [ 84, 144, 230],
#           [ 83, 143, 229],
#           [ 83, 143, 229]],
#
#          [[149, 109,  84],
#           [140,  98,  73],
#           [146,  96,  71],
#           ...,
#           [ 85, 142, 229],
#           [ 85, 142, 229],
#           [ 82, 142, 228]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (14).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.16666667, 0.17666666, 0.77666664, 0.77      ]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[158, 169, 173],
#           [157, 166, 173],
#           [165, 170, 176],
#           ...,
#           [ 91, 157, 243],
#           [ 91, 157, 243],
#           [ 91, 157, 243]],
#
#          [[ 89,  97,  99],
#           [ 92,  92,  92],
#           [122, 114, 103],
#           ...,
#           [ 91, 157, 243],
#           [ 91, 157, 243],
#           [ 91, 157, 243]],
#
#          [[ 32,  36,  37],
#           [ 46,  36,  24],
#           [ 95,  67,  28],
#           ...,
#           [ 90, 156, 242],
#           [ 90, 156, 242],
#           [ 90, 156, 242]],
#
#          ...,
#
#          [[ 96,  59,  67],
#           [ 95,  82,  92],
#           [155, 142, 159],
#           ...,
#           [ 89, 153, 240],
#           [ 89, 153, 240],
#           [ 89, 153, 240]],
#
#          [[ 69,  61,  58],
#           [119, 119, 127],
#           [188, 187, 205],
#           ...,
#           [ 90, 154, 241],
#           [ 90, 154, 241],
#           [ 90, 154, 241]],
#
#          [[100,  97,  92],
#           [167, 167, 175],
#           [188, 193, 212],
#           ...,
#           [ 92, 154, 241],
#           [ 92, 154, 241],
#           [ 92, 154, 241]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (15).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.11333334, 0.12666667, 0.83      , 0.8666667 ]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[169,  95,  84],
#           [168,  94,  85],
#           [169,  92,  84],
#           ...,
#           [ 80, 138, 220],
#           [ 80, 138, 220],
#           [ 80, 138, 220]],
#
#          [[181, 113, 104],
#           [179, 111, 102],
#           [177, 109, 100],
#           ...,
#           [ 80, 138, 220],
#           [ 80, 138, 220],
#           [ 79, 137, 219]],
#
#          [[177, 112, 106],
#           [180, 115, 109],
#           [182, 119, 112],
#           ...,
#           [ 80, 138, 220],
#           [ 80, 138, 220],
#           [ 79, 137, 219]],
#
#          ...,
#
#          [[213, 134, 103],
#           [185, 125,  97],
#           [138, 103,  83],
#           ...,
#           [ 79, 135, 220],
#           [ 78, 134, 219],
#           [ 78, 134, 219]],
#
#          [[213, 132, 102],
#           [183, 126,  99],
#           [134, 102,  81],
#           ...,
#           [ 79, 135, 220],
#           [ 78, 134, 219],
#           [ 78, 134, 219]],
#
#          [[212, 131, 101],
#           [184, 127, 100],
#           [132, 101,  81],
#           ...,
#           [ 79, 135, 222],
#           [ 78, 134, 221],
#           [ 77, 133, 220]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (16).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.08      , 0.31      , 0.74333334, 0.9866667 ]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[111,  55,  64],
#           [181, 102,  89],
#           [196,  99,  67],
#           ...,
#           [ 95, 163, 248],
#           [ 95, 163, 248],
#           [ 94, 162, 247]],
#
#          [[109,  66,  49],
#           [193, 121,  97],
#           [198, 103,  75],
#           ...,
#           [ 95, 163, 248],
#           [ 94, 162, 247],
#           [ 94, 162, 247]],
#
#          [[107,  68,  37],
#           [198, 132, 106],
#           [199, 112,  92],
#           ...,
#           [ 94, 162, 247],
#           [ 94, 162, 247],
#           [ 94, 162, 247]],
#
#          ...,
#
#          [[167, 116,  95],
#           [167, 116,  97],
#           [173, 127, 111],
#           ...,
#           [ 94, 160, 246],
#           [ 94, 160, 246],
#           [ 93, 159, 245]],
#
#          [[205, 164, 144],
#           [175, 137, 126],
#           [159, 128, 134],
#           ...,
#           [ 95, 159, 246],
#           [ 95, 159, 246],
#           [ 94, 158, 245]],
#
#          [[149, 116,  99],
#           [112,  83,  85],
#           [108,  94, 119],
#           ...,
#           [ 95, 159, 246],
#           [ 95, 159, 246],
#           [ 94, 158, 246]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (17).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.15666667, 0.07666667, 0.81666666, 0.84      ]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[ 32,  42,  69],
#           [ 36,  46,  81],
#           [ 32,  44,  92],
#           ...,
#           [ 76, 137, 217],
#           [ 75, 136, 216],
#           [ 75, 136, 216]],
#
#          [[ 16,  23,  39],
#           [ 28,  36,  57],
#           [ 38,  49,  79],
#           ...,
#           [ 76, 137, 217],
#           [ 76, 137, 217],
#           [ 75, 136, 216]],
#
#          [[ 14,  19,  22],
#           [ 12,  20,  23],
#           [ 21,  30,  39],
#           ...,
#           [ 76, 137, 217],
#           [ 76, 137, 217],
#           [ 75, 136, 216]],
#
#          ...,
#
#          [[116,  57,  39],
#           [111,  47,  48],
#           [117,  52,  50],
#           ...,
#           [ 77, 134, 215],
#           [ 77, 134, 215],
#           [ 76, 133, 214]],
#
#          [[112,  53,  49],
#           [112,  49,  58],
#           [114,  49,  55],
#           ...,
#           [ 78, 135, 216],
#           [ 77, 134, 215],
#           [ 76, 133, 214]],
#
#          [[110,  51,  43],
#           [115,  54,  59],
#           [106,  43,  52],
#           ...,
#           [ 77, 134, 215],
#           [ 77, 134, 215],
#           [ 76, 133, 214]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (18).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.09333333, 0.00666667, 0.78      , 0.67      ]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[212, 143, 128],
#           [209, 148, 127],
#           [200, 153, 125],
#           ...,
#           [124, 187, 254],
#           [124, 187, 255],
#           [124, 187, 255]],
#
#          [[183, 122, 103],
#           [175, 119,  94],
#           [185, 142, 110],
#           ...,
#           [124, 187, 254],
#           [124, 187, 255],
#           [124, 187, 255]],
#
#          [[185, 135, 110],
#           [174, 127,  97],
#           [186, 147, 114],
#           ...,
#           [124, 187, 254],
#           [124, 187, 255],
#           [123, 186, 255]],
#
#          ...,
#
#          [[229, 163, 137],
#           [183, 136, 106],
#           [173, 146, 117],
#           ...,
#           [125, 185, 255],
#           [124, 184, 254],
#           [124, 184, 254]],
#
#          [[231, 161, 136],
#           [183, 132, 103],
#           [178, 147, 119],
#           ...,
#           [125, 185, 255],
#           [125, 185, 255],
#           [125, 185, 255]],
#
#          [[235, 160, 137],
#           [185, 129, 102],
#           [184, 150, 123],
#           ...,
#           [127, 186, 255],
#           [127, 186, 255],
#           [126, 185, 255]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (19).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.07333333, 0.05333333, 0.9       , 0.93666667]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[  2,  14,  14],
#           [  9,  18,  17],
#           [ 29,  35,  33],
#           ...,
#           [120, 174, 236],
#           [120, 174, 236],
#           [120, 174, 236]],
#
#          [[  6,  10,   9],
#           [  9,  14,  10],
#           [ 40,  45,  39],
#           ...,
#           [120, 174, 236],
#           [119, 173, 235],
#           [119, 173, 235]],
#
#          [[ 13,  14,   9],
#           [ 12,  13,   7],
#           [ 45,  46,  38],
#           ...,
#           [120, 174, 236],
#           [120, 174, 236],
#           [119, 173, 235]],
#
#          ...,
#
#          [[ 88,  93,  96],
#           [ 71,  75,  74],
#           [ 28,  27,  22],
#           ...,
#           [ 23,  19,  20],
#           [ 24,  20,  21],
#           [ 33,  29,  30]],
#
#          [[138, 140, 139],
#           [154, 153, 149],
#           [ 68,  64,  53],
#           ...,
#           [ 39,  35,  36],
#           [ 28,  24,  25],
#           [ 33,  29,  30]],
#
#          [[183, 181, 182],
#           [176, 173, 168],
#           [120, 112,  99],
#           ...,
#           [ 37,  33,  34],
#           [ 24,  20,  21],
#           [ 30,  26,  27]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (2).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.17      , 0.28333333, 0.99666667, 1.        ]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[ 89, 148, 224],
#           [ 90, 149, 225],
#           [ 90, 149, 225],
#           ...,
#           [ 93, 151, 225],
#           [ 93, 151, 225],
#           [ 93, 151, 225]],
#
#          [[ 89, 148, 224],
#           [ 89, 148, 224],
#           [ 90, 149, 225],
#           ...,
#           [ 93, 151, 225],
#           [ 93, 151, 225],
#           [ 93, 151, 225]],
#
#          [[ 89, 148, 224],
#           [ 89, 148, 224],
#           [ 89, 148, 224],
#           ...,
#           [ 93, 151, 225],
#           [ 93, 151, 225],
#           [ 93, 151, 225]],
#
#          ...,
#
#          [[191, 114,  98],
#           [173,  91,  77],
#           [183,  97,  84],
#           ...,
#           [ 41,  32,  33],
#           [ 38,  29,  30],
#           [ 36,  30,  30]],
#
#          [[190, 115,  96],
#           [172,  91,  74],
#           [182,  96,  81],
#           ...,
#           [ 40,  34,  34],
#           [ 39,  35,  34],
#           [ 39,  35,  34]],
#
#          [[187, 116,  94],
#           [168,  91,  71],
#           [180,  99,  80],
#           ...,
#           [ 38,  32,  32],
#           [ 42,  38,  37],
#           [ 44,  40,  39]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (20).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.28      , 0.05666667, 0.67333335, 0.9633333 ]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[ 90, 149, 225],
#           [ 90, 149, 225],
#           [ 90, 149, 225],
#           ...,
#           [ 92, 149, 226],
#           [ 93, 150, 227],
#           [ 93, 150, 227]],
#
#          [[ 90, 149, 225],
#           [ 90, 149, 225],
#           [ 89, 148, 224],
#           ...,
#           [ 93, 150, 227],
#           [ 93, 150, 227],
#           [ 93, 150, 227]],
#
#          [[ 90, 149, 225],
#           [ 89, 148, 224],
#           [ 89, 148, 224],
#           ...,
#           [ 93, 150, 227],
#           [ 93, 150, 227],
#           [ 93, 150, 227]],
#
#          ...,
#
#          [[242, 244, 243],
#           [241, 245, 244],
#           [241, 245, 244],
#           ...,
#           [ 20,  16,  15],
#           [ 19,  15,  14],
#           [ 20,  16,  13]],
#
#          [[241, 239, 240],
#           [245, 243, 244],
#           [245, 243, 244],
#           ...,
#           [ 17,  15,  16],
#           [ 17,  15,  16],
#           [ 18,  16,  17]],
#
#          [[239, 235, 234],
#           [245, 241, 240],
#           [246, 242, 243],
#           ...,
#           [ 19,  17,  18],
#           [ 19,  17,  18],
#           [ 21,  19,  20]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (21).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.26      , 0.04333333, 0.77      , 0.98      ]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[ 57,  56,  61],
#           [ 58,  58,  60],
#           [ 57,  57,  59],
#           ...,
#           [ 60, 103, 171],
#           [ 59, 102, 170],
#           [ 59, 102, 170]],
#
#          [[ 57,  56,  61],
#           [ 57,  56,  61],
#           [ 57,  57,  59],
#           ...,
#           [ 60, 103, 171],
#           [ 60, 103, 171],
#           [ 60, 103, 171]],
#
#          [[ 56,  55,  60],
#           [ 57,  56,  61],
#           [ 57,  56,  61],
#           ...,
#           [ 61, 104, 172],
#           [ 60, 103, 171],
#           [ 60, 103, 171]],
#
#          ...,
#
#          [[ 57,  57,  65],
#           [ 58,  58,  66],
#           [ 58,  58,  66],
#           ...,
#           [ 58, 101, 170],
#           [ 60, 100, 170],
#           [ 60, 100, 170]],
#
#          [[ 58,  58,  66],
#           [ 58,  58,  66],
#           [ 58,  58,  66],
#           ...,
#           [ 60, 100, 170],
#           [ 60, 100, 170],
#           [ 60, 100, 170]],
#
#          [[ 59,  59,  67],
#           [ 58,  58,  66],
#           [ 59,  59,  67],
#           ...,
#           [ 60, 100, 170],
#           [ 60, 100, 170],
#           [ 61,  99, 170]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (22).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(2, 4) dtype=float32, numpy=
#   array([[0.28333333, 0.63      , 0.70666665, 0.99333334],
#          [0.23333333, 0.00333333, 0.54      , 0.79333335]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(2,) dtype=int64, numpy=array([1, 3], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[ 37,  33,  32],
#           [ 37,  36,  34],
#           [ 24,  24,  24],
#           ...,
#           [ 62, 111, 180],
#           [ 62, 109, 179],
#           [ 62, 109, 177]],
#
#          [[ 39,  38,  36],
#           [ 38,  37,  35],
#           [ 25,  25,  25],
#           ...,
#           [ 62, 111, 180],
#           [ 61, 110, 179],
#           [ 62, 109, 177]],
#
#          [[ 40,  42,  41],
#           [ 38,  38,  38],
#           [ 26,  26,  26],
#           ...,
#           [ 62, 111, 180],
#           [ 62, 111, 180],
#           [ 61, 110, 179]],
#
#          ...,
#
#          [[ 57,  56,  62],
#           [ 59,  58,  64],
#           [ 57,  56,  62],
#           ...,
#           [ 64, 109, 177],
#           [ 64, 109, 176],
#           [ 63, 108, 175]],
#
#          [[ 60,  59,  65],
#           [ 58,  57,  63],
#           [ 56,  55,  61],
#           ...,
#           [ 64, 109, 177],
#           [ 63, 108, 175],
#           [ 63, 108, 175]],
#
#          [[ 60,  59,  65],
#           [ 55,  54,  60],
#           [ 56,  55,  61],
#           ...,
#           [ 64, 109, 177],
#           [ 63, 108, 175],
#           [ 64, 107, 175]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (23).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(2, 4) dtype=float32, numpy=
#   array([[0.29333332, 0.19333333, 0.68333334, 0.62      ],
#          [0.23      , 0.69666666, 0.49      , 0.9766667 ]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(2,) dtype=int64, numpy=array([1, 6], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[100, 101,  95],
#           [120, 120, 110],
#           [137, 135, 123],
#           ...,
#           [ 55,  99, 164],
#           [ 56,  97, 163],
#           [ 55,  96, 160]],
#
#          [[ 30,  34,  46],
#           [ 36,  38,  50],
#           [ 44,  44,  52],
#           ...,
#           [ 56, 100, 165],
#           [ 57,  98, 164],
#           [ 56,  97, 161]],
#
#          [[ 16,  22,  48],
#           [ 21,  25,  50],
#           [ 26,  26,  50],
#           ...,
#           [ 56, 100, 165],
#           [ 55,  99, 164],
#           [ 56,  97, 161]],
#
#          ...,
#
#          [[ 12,  25,  42],
#           [ 14,  23,  38],
#           [ 15,  21,  33],
#           ...,
#           [ 60,  99, 164],
#           [ 60,  98, 161],
#           [ 59,  97, 160]],
#
#          [[ 11,  23,  39],
#           [ 13,  23,  35],
#           [ 14,  20,  32],
#           ...,
#           [ 61,  99, 162],
#           [ 60,  98, 161],
#           [ 58,  96, 159]],
#
#          [[ 12,  22,  34],
#           [ 13,  21,  34],
#           [ 13,  21,  34],
#           ...,
#           [ 61,  99, 162],
#           [ 60,  98, 161],
#           [ 58,  96, 159]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (24).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(2, 4) dtype=float32, numpy=
#   array([[0.16333333, 0.09      , 0.55333334, 0.50333333],
#          [0.14666666, 0.61333334, 0.37      , 0.8666667 ]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(2,) dtype=int64, numpy=array([1, 6], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[ 28,  29,  33],
#           [ 35,  36,  40],
#           [ 31,  32,  37],
#           ...,
#           [ 75, 134, 214],
#           [ 74, 133, 213],
#           [ 73, 132, 212]],
#
#          [[ 27,  28,  32],
#           [ 33,  34,  38],
#           [ 32,  33,  38],
#           ...,
#           [ 75, 134, 214],
#           [ 74, 133, 213],
#           [ 73, 132, 212]],
#
#          [[ 29,  30,  34],
#           [ 34,  35,  39],
#           [ 43,  44,  49],
#           ...,
#           [ 73, 134, 214],
#           [ 75, 134, 214],
#           [ 74, 133, 213]],
#
#          ...,
#
#          [[ 57,  56,  61],
#           [ 55,  54,  59],
#           [ 53,  52,  57],
#           ...,
#           [ 74, 131, 210],
#           [ 73, 130, 209],
#           [ 72, 129, 208]],
#
#          [[ 58,  57,  62],
#           [ 56,  55,  60],
#           [ 52,  51,  56],
#           ...,
#           [ 74, 131, 212],
#           [ 73, 130, 209],
#           [ 72, 129, 208]],
#
#          [[ 59,  59,  61],
#           [ 56,  55,  60],
#           [ 52,  51,  56],
#           ...,
#           [ 75, 130, 212],
#           [ 73, 128, 210],
#           [ 73, 128, 208]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (25).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(2, 4) dtype=float32, numpy=
#   array([[0.36666667, 0.29      , 0.78      , 0.6933333 ],
#          [0.32333332, 0.80333334, 0.61333334, 0.99666667]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(2,) dtype=int64, numpy=array([1, 6], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[130, 187, 242],
#           [129, 186, 241],
#           [129, 186, 241],
#           ...,
#           [  7,   7,   9],
#           [  7,   8,  10],
#           [  8,   9,  11]],
#
#          [[130, 187, 242],
#           [129, 186, 241],
#           [129, 186, 241],
#           ...,
#           [  8,   8,  10],
#           [  7,   8,  10],
#           [  7,   8,  10]],
#
#          [[130, 187, 242],
#           [129, 186, 241],
#           [129, 186, 241],
#           ...,
#           [  7,   7,   9],
#           [  6,   7,   9],
#           [  6,   8,   7]],
#
#          ...,
#
#          [[136, 191, 247],
#           [136, 191, 247],
#           [137, 192, 248],
#           ...,
#           [ 65,  41,  39],
#           [ 64,  40,  38],
#           [ 61,  40,  37]],
#
#          [[136, 191, 247],
#           [137, 192, 248],
#           [137, 192, 248],
#           ...,
#           [ 67,  37,  37],
#           [ 66,  36,  36],
#           [ 64,  36,  35]],
#
#          [[138, 190, 247],
#           [139, 191, 248],
#           [139, 191, 248],
#           ...,
#           [ 70,  34,  36],
#           [ 69,  33,  35],
#           [ 68,  34,  35]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (26).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.19      , 0.14333333, 0.99      , 0.7033333 ]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[210, 247, 255],
#           [210, 247, 255],
#           [210, 247, 255],
#           ...,
#           [ 19,  20,  25],
#           [ 20,  19,  24],
#           [ 21,  20,  25]],
#
#          [[210, 247, 255],
#           [210, 247, 255],
#           [210, 247, 255],
#           ...,
#           [ 20,  21,  26],
#           [ 20,  19,  24],
#           [ 20,  19,  24]],
#
#          [[210, 247, 255],
#           [210, 247, 255],
#           [210, 247, 255],
#           ...,
#           [ 21,  22,  27],
#           [ 20,  21,  25],
#           [ 20,  21,  25]],
#
#          ...,
#
#          [[213, 253, 255],
#           [214, 254, 255],
#           [214, 254, 255],
#           ...,
#           [107, 130, 144],
#           [120, 146, 161],
#           [127, 150, 168]],
#
#          [[214, 254, 255],
#           [214, 254, 255],
#           [214, 254, 255],
#           ...,
#           [108, 131, 145],
#           [118, 144, 161],
#           [124, 147, 165]],
#
#          [[213, 253, 255],
#           [214, 254, 255],
#           [214, 254, 255],
#           ...,
#           [107, 130, 146],
#           [115, 141, 158],
#           [120, 143, 161]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (27).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.05333333, 0.06      , 0.99333334, 0.8666667 ]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[ 38,  43,  46],
#           [ 44,  49,  53],
#           [ 55,  58,  65],
#           ...,
#           [101, 137, 197],
#           [100, 136, 196],
#           [100, 136, 196]],
#
#          [[ 41,  44,  49],
#           [ 51,  54,  59],
#           [ 70,  70,  78],
#           ...,
#           [102, 138, 198],
#           [102, 138, 198],
#           [101, 137, 197]],
#
#          [[ 44,  47,  56],
#           [ 50,  50,  60],
#           [ 85,  83,  94],
#           ...,
#           [101, 137, 197],
#           [102, 138, 198],
#           [102, 138, 198]],
#
#          ...,
#
#          [[ 39,  52,  69],
#           [ 40,  53,  70],
#           [ 39,  52,  69],
#           ...,
#           [ 52,  31,  28],
#           [ 47,  28,  24],
#           [ 44,  24,  23]],
#
#          [[ 39,  52,  69],
#           [ 41,  52,  70],
#           [ 40,  51,  69],
#           ...,
#           [ 37,  19,  15],
#           [ 32,  17,  14],
#           [ 30,  15,  12]],
#
#          [[ 42,  54,  70],
#           [ 43,  55,  71],
#           [ 41,  53,  69],
#           ...,
#           [ 30,  15,  10],
#           [ 25,  11,   8],
#           [ 22,   8,   5]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (28).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.32      , 0.21333334, 0.75      , 0.83666664]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[ 65,  48,  58],
#           [ 77,  57,  66],
#           [ 90,  71,  77],
#           ...,
#           [100, 135, 193],
#           [100, 135, 193],
#           [100, 135, 193]],
#
#          [[ 64,  47,  55],
#           [ 72,  52,  61],
#           [ 86,  69,  75],
#           ...,
#           [100, 135, 193],
#           [100, 135, 193],
#           [100, 135, 193]],
#
#          [[ 77,  58,  64],
#           [ 83,  64,  70],
#           [ 77,  62,  69],
#           ...,
#           [100, 135, 193],
#           [100, 135, 193],
#           [100, 135, 193]],
#
#          ...,
#
#          [[ 53,  63,  75],
#           [ 57,  67,  79],
#           [ 56,  66,  78],
#           ...,
#           [  5,   6,  10],
#           [  4,   5,   9],
#           [  4,   5,   9]],
#
#          [[ 49,  58,  73],
#           [ 54,  63,  78],
#           [ 53,  62,  77],
#           ...,
#           [  4,   5,   9],
#           [  5,   6,  10],
#           [  5,   6,  10]],
#
#          [[ 52,  61,  76],
#           [ 56,  65,  80],
#           [ 55,  64,  79],
#           ...,
#           [  4,   5,   9],
#           [  5,   6,  10],
#           [  5,   6,  10]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (29).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.24      , 0.24333334, 0.69      , 0.8933333 ]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[ 78,  80,  69],
#           [ 95,  92,  85],
#           [ 54,  44,  45],
#           ...,
#           [ 83, 136, 212],
#           [ 84, 137, 213],
#           [ 84, 137, 213]],
#
#          [[ 46,  37,  28],
#           [ 46,  35,  29],
#           [ 35,  23,  23],
#           ...,
#           [ 83, 136, 212],
#           [ 84, 137, 213],
#           [ 84, 137, 213]],
#
#          [[ 49,  31,  21],
#           [ 39,  22,  14],
#           [ 30,  19,  17],
#           ...,
#           [ 84, 137, 213],
#           [ 83, 136, 212],
#           [ 83, 136, 212]],
#
#          ...,
#
#          [[251, 225, 226],
#           [204, 193, 187],
#           [175, 161, 152],
#           ...,
#           [ 79, 132, 212],
#           [ 78, 131, 211],
#           [ 78, 131, 211]],
#
#          [[237, 203, 201],
#           [154, 116, 113],
#           [179, 130, 126],
#           ...,
#           [ 79, 132, 212],
#           [ 78, 131, 211],
#           [ 79, 130, 211]],
#
#          [[220, 190, 182],
#           [149,  91,  90],
#           [163,  84,  87],
#           ...,
#           [ 79, 130, 211],
#           [ 79, 130, 211],
#           [ 79, 130, 211]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (3).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.14333333, 0.15      , 0.7       , 0.76666665]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[ 44,  39,  59],
#           [ 47,  44,  61],
#           [ 52,  49,  66],
#           ...,
#           [123, 156, 209],
#           [122, 155, 208],
#           [121, 154, 207]],
#
#          [[ 45,  41,  58],
#           [ 50,  47,  64],
#           [ 49,  46,  63],
#           ...,
#           [123, 156, 209],
#           [123, 156, 209],
#           [122, 155, 208]],
#
#          [[ 49,  45,  62],
#           [ 45,  42,  59],
#           [ 44,  43,  59],
#           ...,
#           [124, 157, 210],
#           [123, 156, 209],
#           [123, 156, 209]],
#
#          ...,
#
#          [[ 63,  73,  83],
#           [ 63,  73,  83],
#           [ 65,  75,  85],
#           ...,
#           [ 78,  80,  79],
#           [ 77,  79,  78],
#           [ 75,  77,  76]],
#
#          [[ 59,  69,  79],
#           [ 59,  69,  79],
#           [ 62,  70,  81],
#           ...,
#           [ 73,  75,  74],
#           [ 72,  74,  73],
#           [ 72,  74,  73]],
#
#          [[ 63,  72,  81],
#           [ 61,  70,  79],
#           [ 63,  72,  81],
#           ...,
#           [ 70,  72,  71],
#           [ 70,  72,  71],
#           [ 70,  72,  71]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (30).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.31      , 0.06666667, 0.7633333 , 0.81333333]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[164, 206, 254],
#           [164, 206, 254],
#           [164, 206, 254],
#           ...,
#           [ 37,  25,  49],
#           [ 37,  25,  49],
#           [ 40,  28,  52]],
#
#          [[164, 206, 254],
#           [164, 206, 254],
#           [164, 206, 254],
#           ...,
#           [ 35,  25,  50],
#           [ 38,  28,  53],
#           [ 40,  30,  55]],
#
#          [[164, 206, 254],
#           [164, 206, 254],
#           [164, 206, 254],
#           ...,
#           [ 38,  29,  56],
#           [ 38,  29,  56],
#           [ 36,  27,  54]],
#
#          ...,
#
#          [[ 62,  88,  75],
#           [ 71,  97,  84],
#           [ 52,  78,  67],
#           ...,
#           [204, 123,  96],
#           [232, 158, 131],
#           [237, 170, 143]],
#
#          [[ 64,  90,  77],
#           [ 72,  98,  85],
#           [ 50,  76,  65],
#           ...,
#           [210, 126, 100],
#           [233, 158, 129],
#           [237, 168, 139]],
#
#          [[ 61,  87,  74],
#           [ 58,  84,  73],
#           [ 47,  73,  62],
#           ...,
#           [219, 135, 107],
#           [237, 162, 133],
#           [240, 171, 142]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (31).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.06666667, 0.02      , 1.        , 0.9533333 ]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[166, 206, 255],
#           [166, 207, 253],
#           [167, 208, 254],
#           ...,
#           [ 42,  37,  57],
#           [ 37,  32,  52],
#           [ 39,  35,  52]],
#
#          [[166, 206, 255],
#           [166, 207, 253],
#           [167, 208, 254],
#           ...,
#           [ 47,  42,  62],
#           [ 43,  38,  58],
#           [ 40,  36,  53]],
#
#          [[167, 207, 255],
#           [167, 207, 255],
#           [167, 208, 254],
#           ...,
#           [ 37,  32,  52],
#           [ 35,  30,  50],
#           [ 30,  22,  43]],
#
#          ...,
#
#          [[ 64,  84,  73],
#           [ 68,  88,  79],
#           [ 78,  99,  90],
#           ...,
#           [235, 171, 146],
#           [234, 168, 146],
#           [237, 169, 150]],
#
#          [[ 67,  83,  73],
#           [ 83, 100,  90],
#           [ 94, 116, 104],
#           ...,
#           [236, 170, 144],
#           [235, 169, 145],
#           [240, 169, 149]],
#
#          [[ 65,  78,  69],
#           [ 60,  76,  66],
#           [ 65,  85,  74],
#           ...,
#           [237, 171, 145],
#           [237, 171, 147],
#           [238, 170, 149]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (32).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.10666667, 0.01666667, 0.99      , 0.97333336]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[177, 220, 255],
#           [177, 220, 255],
#           [177, 220, 255],
#           ...,
#           [149, 202, 255],
#           [149, 202, 255],
#           [148, 201, 255]],
#
#          [[177, 220, 255],
#           [177, 220, 255],
#           [177, 220, 255],
#           ...,
#           [149, 202, 255],
#           [149, 202, 255],
#           [149, 202, 255]],
#
#          [[177, 220, 255],
#           [177, 220, 255],
#           [177, 220, 255],
#           ...,
#           [149, 202, 255],
#           [149, 202, 255],
#           [149, 202, 255]],
#
#          ...,
#
#          [[250, 207, 198],
#           [255, 213, 208],
#           [237, 172, 176],
#           ...,
#           [245, 195, 168],
#           [243, 193, 166],
#           [241, 192, 162]],
#
#          [[255, 214, 202],
#           [252, 212, 204],
#           [236, 181, 178],
#           ...,
#           [247, 197, 170],
#           [243, 192, 163],
#           [241, 187, 159]],
#
#          [[255, 212, 206],
#           [252, 209, 203],
#           [239, 181, 179],
#           ...,
#           [246, 195, 168],
#           [244, 188, 161],
#           [243, 183, 157]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (33).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.06333333, 0.03333334, 0.9766667 , 0.98      ]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[ 99, 161, 248],
#           [100, 162, 249],
#           [102, 162, 250],
#           ...,
#           [ 88, 153, 247],
#           [ 88, 153, 247],
#           [ 88, 153, 247]],
#
#          [[101, 161, 249],
#           [101, 161, 249],
#           [102, 162, 250],
#           ...,
#           [ 88, 153, 247],
#           [ 88, 153, 247],
#           [ 88, 153, 247]],
#
#          [[101, 161, 249],
#           [101, 161, 249],
#           [101, 161, 249],
#           ...,
#           [ 89, 154, 248],
#           [ 89, 154, 248],
#           [ 88, 153, 247]],
#
#          ...,
#
#          [[ 81, 158, 168],
#           [ 77, 154, 164],
#           [ 75, 152, 162],
#           ...,
#           [245, 201, 174],
#           [242, 198, 171],
#           [241, 197, 172]],
#
#          [[ 67, 144, 154],
#           [ 64, 141, 151],
#           [ 66, 143, 153],
#           ...,
#           [216, 168, 146],
#           [208, 160, 138],
#           [198, 150, 128]],
#
#          [[ 67, 141, 150],
#           [ 75, 149, 158],
#           [ 86, 160, 169],
#           ...,
#           [137,  89,  67],
#           [133,  82,  61],
#           [122,  70,  49]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (34).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.1       , 0.04333333, 0.9433333 , 0.97333336]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[100, 162, 249],
#           [101, 163, 250],
#           [102, 164, 251],
#           ...,
#           [ 92, 153, 246],
#           [ 91, 152, 245],
#           [ 91, 152, 243]],
#
#          [[101, 163, 250],
#           [101, 163, 250],
#           [102, 164, 251],
#           ...,
#           [ 92, 153, 246],
#           [ 92, 153, 246],
#           [ 92, 153, 246]],
#
#          [[102, 164, 251],
#           [101, 163, 250],
#           [102, 162, 250],
#           ...,
#           [ 92, 153, 246],
#           [ 91, 152, 245],
#           [ 91, 152, 245]],
#
#          ...,
#
#          [[ 64, 144, 153],
#           [ 53, 133, 142],
#           [ 70, 150, 159],
#           ...,
#           [238, 185, 153],
#           [232, 178, 142],
#           [226, 170, 135]],
#
#          [[ 58, 138, 145],
#           [ 52, 132, 139],
#           [ 64, 142, 152],
#           ...,
#           [157, 106,  77],
#           [192, 143, 111],
#           [223, 174, 142]],
#
#          [[ 70, 149, 156],
#           [ 63, 142, 149],
#           [ 64, 143, 150],
#           ...,
#           [183, 133, 106],
#           [214, 167, 139],
#           [226, 181, 152]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (35).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.1       , 0.04333333, 0.98      , 0.93      ]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[ 90, 129, 204],
#           [ 91, 130, 205],
#           [ 91, 130, 205],
#           ...,
#           [ 79, 120, 199],
#           [ 78, 119, 198],
#           [ 78, 119, 198]],
#
#          [[ 91, 130, 205],
#           [ 91, 130, 205],
#           [ 91, 130, 205],
#           ...,
#           [ 79, 120, 199],
#           [ 79, 120, 199],
#           [ 79, 120, 199]],
#
#          [[ 92, 131, 206],
#           [ 92, 131, 206],
#           [ 92, 131, 206],
#           ...,
#           [ 79, 120, 199],
#           [ 79, 120, 199],
#           [ 79, 120, 199]],
#
#          ...,
#
#          [[112, 120, 123],
#           [126, 133, 139],
#           [117, 126, 133],
#           ...,
#           [255, 243, 245],
#           [255, 253, 250],
#           [225, 211, 211]],
#
#          [[139, 147, 149],
#           [120, 128, 130],
#           [101, 110, 115],
#           ...,
#           [248, 229, 231],
#           [255, 242, 243],
#           [255, 233, 236]],
#
#          [[ 99, 105, 103],
#           [ 69,  78,  77],
#           [ 52,  62,  63],
#           ...,
#           [209, 189, 191],
#           [225, 203, 206],
#           [226, 204, 207]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (36).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.16      , 0.06333333, 0.8933333 , 0.87666667]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[ 88, 126, 197],
#           [ 91, 129, 200],
#           [ 93, 131, 202],
#           ...,
#           [ 82, 121, 196],
#           [ 81, 120, 195],
#           [ 80, 119, 194]],
#
#          [[ 91, 129, 200],
#           [ 92, 130, 201],
#           [ 93, 131, 202],
#           ...,
#           [ 83, 122, 197],
#           [ 82, 121, 196],
#           [ 81, 120, 195]],
#
#          [[ 92, 130, 201],
#           [ 93, 131, 202],
#           [ 93, 131, 202],
#           ...,
#           [ 83, 122, 197],
#           [ 83, 122, 197],
#           [ 82, 121, 196]],
#
#          ...,
#
#          [[ 86,  95, 102],
#           [ 80,  89,  96],
#           [ 79,  88,  97],
#           ...,
#           [223, 188, 195],
#           [243, 227, 228],
#           [248, 253, 247]],
#
#          [[ 90,  97, 103],
#           [ 68,  77,  84],
#           [ 55,  64,  73],
#           ...,
#           [243, 229, 228],
#           [248, 238, 236],
#           [255, 254, 251]],
#
#          [[ 69,  77,  80],
#           [ 54,  63,  68],
#           [ 43,  52,  59],
#           ...,
#           [218, 221, 214],
#           [223, 224, 219],
#           [253, 248, 245]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'basantapur_tower (37).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.14      , 0.07666667, 0.87      , 0.92333335]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([1], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[ 91, 129, 200],
#           [ 92, 130, 201],
#           [ 93, 131, 202],
#           ...,
#           [ 81, 123, 199],
#           [ 80, 122, 198],
#           [ 78, 120, 196]],
#
#          [[ 92, 130, 201],
#           [ 92, 130, 201],
#           [ 93, 131, 202],
#           ...,
#           [ 80, 122, 198],
#           [ 79, 121, 197],
#           [ 78, 120, 196]],
#
#          [[ 93, 131, 202],
#           [ 93, 131, 202],
#           [ 93, 131, 202],
#           ...,
#           [ 81, 123, 199],
#           [ 81, 123, 199],
#           [ 80, 122, 198]],
#
#          ...,
#
#          [[ 45,  53,  64],
#           [ 35,  43,  54],
#           [ 61,  69,  80],
#           ...,
#           [245, 255, 253],
#           [250, 255, 252],
# ...
#           [ 34,  34,  26]],
#
#          [[122, 107,  84],
#           [129, 114,  93],
#           [135, 118,  98],
#           ...,
#           [ 41,  33,  22],
#           [ 36,  29,  21],
#           [ 36,  31,  25]],
#
#          [[127, 112,  89],
#           [116, 101,  78],
#           [141, 125, 102],
#           ...,
#           [ 43,  30,  22],
#           [ 39,  28,  22],
#           [ 35,  26,  21]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'trailokya_mohan (83).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.00333333, 0.11      , 1.        , 0.91      ]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([7], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[209, 227, 251],
#           [209, 227, 251],
#           [209, 227, 251],
#           ...,
#           [ 86,  87,  89],
#           [ 73,  74,  76],
#           [ 63,  63,  63]],
#
#          [[209, 227, 251],
#           [209, 227, 251],
#           [209, 227, 251],
#           ...,
#           [ 59,  59,  57],
#           [ 58,  58,  56],
#           [ 57,  56,  54]],
#
#          [[209, 227, 249],
#           [209, 227, 249],
#           [209, 227, 249],
#           ...,
#           [ 56,  53,  48],
#           [ 59,  58,  53],
#           [ 60,  59,  54]],
#
#          ...,
#
#          [[172, 196, 234],
#           [172, 196, 234],
#           [172, 196, 234],
#           ...,
#           [112, 102,  93],
#           [111, 101,  92],
#           [103,  93,  84]],
#
#          [[172, 196, 234],
#           [172, 196, 234],
#           [172, 196, 234],
#           ...,
#           [120, 107,  99],
#           [116, 106,  97],
#           [105,  95,  86]],
#
#          [[171, 195, 233],
#           [172, 196, 234],
#           [172, 196, 234],
#           ...,
#           [120, 107,  99],
#           [117, 107,  98],
#           [104,  94,  85]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'trailokya_mohan (84).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(2, 4) dtype=float32, numpy=
#   array([[0.29666665, 0.12333333, 0.87333333, 0.9866667 ],
#          [0.72333336, 0.07666667, 1.        , 0.53333336]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(2,) dtype=int64, numpy=array([7, 4], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[142, 175, 216],
#           [142, 175, 216],
#           [142, 175, 216],
#           ...,
#           [ 14,  10,   7],
#           [ 20,  16,  13],
#           [ 26,  21,  17]],
#
#          [[141, 174, 215],
#           [141, 174, 215],
#           [142, 175, 216],
#           ...,
#           [ 27,  23,  20],
#           [ 29,  25,  22],
#           [ 32,  29,  24]],
#
#          [[141, 174, 215],
#           [141, 174, 215],
#           [141, 174, 215],
#           ...,
#           [ 27,  23,  20],
#           [ 28,  25,  20],
#           [ 28,  25,  20]],
#
#          ...,
#
#          [[140, 173, 218],
#           [140, 173, 218],
#           [140, 173, 218],
#           ...,
#           [191, 190, 186],
#           [189, 188, 186],
#           [185, 184, 182]],
#
#          [[140, 173, 218],
#           [140, 173, 218],
#           [140, 173, 218],
#           ...,
#           [189, 188, 184],
#           [188, 187, 185],
#           [185, 184, 182]],
#
#          [[140, 173, 218],
#           [140, 173, 218],
#           [140, 173, 218],
#           ...,
#           [189, 188, 184],
#           [189, 188, 186],
#           [188, 187, 185]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'trailokya_mohan (85).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.22      , 0.02333333, 1.        , 1.        ]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([7], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[165, 202, 244],
#           [165, 202, 244],
#           [165, 202, 244],
#           ...,
#           [ 22,  18,  19],
#           [ 23,  19,  20],
#           [ 21,  17,  16]],
#
#          [[165, 202, 244],
#           [165, 202, 244],
#           [165, 202, 244],
#           ...,
#           [ 20,  14,  16],
#           [ 23,  17,  17],
#           [ 23,  17,  17]],
#
#          [[165, 202, 244],
#           [165, 202, 244],
#           [165, 202, 244],
#           ...,
#           [ 21,  15,  15],
#           [ 24,  19,  16],
#           [ 24,  19,  16]],
#
#          ...,
#
#          [[167, 204, 246],
#           [167, 204, 246],
#           [168, 205, 247],
#           ...,
#           [119, 124, 127],
#           [120, 125, 128],
#           [120, 125, 128]],
#
#          [[167, 204, 246],
#           [167, 204, 246],
#           [168, 205, 247],
#           ...,
#           [101, 109, 112],
#           [101, 109, 112],
#           [104, 109, 112]],
#
#          [[167, 204, 246],
#           [167, 204, 246],
#           [168, 205, 247],
#           ...,
#           [ 98, 103, 107],
#           [ 97, 102, 105],
#           [ 95, 100, 103]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'trailokya_mohan (86).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(2, 4) dtype=float32, numpy=
#   array([[0.17      , 0.12666667, 1.        , 1.        ],
#          [0.50666666, 0.00666667, 1.        , 0.38666666]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(2,) dtype=int64, numpy=array([7, 2], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[147, 189, 229],
#           [147, 189, 229],
#           [147, 189, 229],
#           ...,
#           [ 15,   9,   9],
#           [ 17,  11,  13],
#           [ 20,  14,  16]],
#
#          [[147, 189, 229],
#           [147, 189, 229],
#           [147, 189, 229],
#           ...,
#           [ 17,  11,  11],
#           [ 15,   9,  11],
#           [ 15,   9,  11]],
#
#          [[147, 189, 229],
#           [147, 189, 229],
#           [147, 189, 229],
#           ...,
#           [ 16,  10,  10],
#           [ 15,   9,  11],
#           [ 14,   8,  10]],
#
#          ...,
#
#          [[149, 191, 233],
#           [149, 191, 233],
#           [150, 192, 234],
#           ...,
#           [187, 179, 168],
#           [187, 179, 168],
#           [174, 166, 155]],
#
#          [[149, 191, 233],
#           [149, 191, 233],
#           [150, 192, 234],
#           ...,
#           [193, 185, 172],
#           [194, 186, 175],
#           [190, 182, 171]],
#
#          [[149, 191, 233],
#           [149, 191, 233],
#           [150, 192, 234],
#           ...,
#           [187, 177, 165],
#           [189, 179, 169],
#           [189, 181, 170]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'trailokya_mohan (87).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.12333333, 0.00333333, 1.        , 0.99333334]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([7], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[254, 254, 254],
#           [254, 254, 254],
#           [254, 254, 254],
#           ...,
#           [ 29,  29,  17],
#           [ 32,  32,  22],
#           [ 73,  73,  65]],
#
#          [[254, 254, 254],
#           [254, 254, 254],
#           [254, 254, 254],
#           ...,
#           [ 29,  29,  17],
#           [ 31,  31,  21],
#           [ 72,  72,  64]],
#
#          [[254, 254, 254],
#           [254, 254, 254],
#           [254, 254, 254],
#           ...,
#           [ 30,  30,  20],
#           [ 31,  31,  21],
#           [ 72,  69,  62]],
#
#          ...,
#
#          [[208, 222, 231],
#           [208, 222, 231],
#           [209, 223, 232],
#           ...,
#           [  4,   5,   0],
#           [  4,   4,   2],
#           [  4,   4,   2]],
#
#          [[208, 222, 231],
#           [208, 222, 231],
#           [208, 222, 231],
#           ...,
#           [  3,   3,   1],
#           [  3,   3,   1],
#           [  3,   3,   1]],
#
#          [[208, 222, 231],
#           [208, 222, 231],
#           [208, 222, 231],
#           ...,
#           [  4,   4,   2],
#           [  3,   5,   2],
#           [  3,   3,   1]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'trailokya_mohan (88).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.02      , 0.01      , 0.88666666, 0.7866667 ]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([7], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[190, 229, 244],
#           [190, 229, 244],
#           [190, 229, 244],
#           ...,
#           [128, 163, 183],
#           [128, 163, 183],
#           [130, 162, 183]],
#
#          [[191, 230, 245],
#           [191, 230, 245],
#           [190, 229, 244],
#           ...,
#           [128, 163, 183],
#           [128, 163, 183],
#           [128, 163, 183]],
#
#          [[192, 231, 246],
#           [192, 231, 246],
#           [191, 230, 245],
#           ...,
#           [128, 163, 183],
#           [128, 163, 183],
#           [128, 163, 183]],
#
#          ...,
#
#          [[105, 124, 122],
#           [104, 123, 121],
#           [108, 124, 123],
#           ...,
#           [100, 132, 129],
#           [ 99, 131, 128],
#           [ 96, 131, 127]],
#
#          [[106, 126, 124],
#           [105, 125, 123],
#           [106, 126, 124],
#           ...,
#           [102, 134, 131],
#           [101, 133, 130],
#           [100, 132, 129]],
#
#          [[107, 129, 126],
#           [106, 129, 123],
#           [107, 130, 124],
#           ...,
#           [102, 134, 131],
#           [102, 134, 131],
#           [100, 135, 131]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'trailokya_mohan (89).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.06, 0.1 , 0.88, 0.69]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([7], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[ 11,  15,  18],
#           [ 14,  18,  21],
#           [ 18,  19,  23],
#           ...,
#           [245, 255, 255],
#           [245, 255, 255],
#           [245, 255, 255]],
#
#          [[ 15,  16,  18],
#           [ 16,  17,  19],
#           [ 17,  18,  20],
#           ...,
#           [245, 255, 255],
#           [245, 255, 255],
#           [244, 254, 255]],
#
#          [[ 17,  18,  20],
#           [ 16,  17,  19],
#           [ 16,  17,  19],
#           ...,
#           [245, 255, 255],
#           [244, 254, 255],
#           [244, 254, 255]],
#
#          ...,
#
#          [[ 95,  79,  66],
#           [ 98,  80,  68],
#           [ 94,  74,  63],
#           ...,
#           [202, 225, 255],
#           [202, 225, 255],
#           [201, 224, 255]],
#
#          [[ 95,  77,  65],
#           [ 96,  78,  66],
#           [ 95,  75,  64],
#           ...,
#           [202, 225, 255],
#           [202, 225, 255],
#           [201, 224, 255]],
#
#          [[ 89,  71,  59],
#           [ 90,  72,  60],
#           [ 93,  73,  64],
#           ...,
#           [202, 225, 255],
#           [202, 225, 255],
#           [201, 224, 255]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'trailokya_mohan (9).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.11666667, 0.05333333, 0.79333335, 1.        ]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([7], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[184, 248, 248],
#           [184, 248, 248],
#           [186, 248, 247],
#           ...,
#           [118, 170, 192],
#           [118, 170, 191],
#           [118, 170, 191]],
#
#          [[185, 249, 249],
#           [185, 249, 249],
#           [187, 249, 248],
#           ...,
#           [116, 171, 192],
#           [118, 170, 192],
#           [118, 170, 191]],
#
#          [[186, 250, 250],
#           [186, 250, 250],
#           [187, 248, 249],
#           ...,
#           [116, 171, 192],
#           [118, 170, 192],
#           [118, 170, 191]],
#
#          ...,
#
#          [[114, 119, 112],
#           [114, 119, 112],
#           [113, 118, 112],
#           ...,
#           [111, 109,  97],
#           [110, 108,  96],
#           [110, 108,  96]],
#
#          [[113, 118, 111],
#           [113, 118, 111],
#           [113, 118, 112],
#           ...,
#           [115, 118, 111],
#           [115, 118, 111],
#           [115, 118, 111]],
#
#          [[113, 116, 109],
#           [111, 116, 109],
#           [112, 117, 111],
#           ...,
#           [114, 120, 118],
#           [115, 121, 117],
#           [114, 123, 118]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'trailokya_mohan (90).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.23      , 0.13333334, 1.        , 0.70666665]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([7], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[168, 226, 240],
#           [168, 225, 242],
#           [168, 225, 242],
#           ...,
#           [104, 156, 180],
#           [104, 156, 180],
#           [104, 155, 182]],
#
#          [[170, 226, 243],
#           [170, 226, 243],
#           [170, 226, 243],
#           ...,
#           [105, 155, 182],
#           [105, 155, 182],
#           [103, 154, 181]],
#
#          [[171, 227, 244],
#           [171, 227, 244],
#           [171, 227, 244],
#           ...,
#           [106, 156, 183],
#           [105, 155, 182],
#           [105, 155, 182]],
#
#          ...,
#
#          [[108, 117, 114],
#           [106, 115, 112],
#           [107, 116, 113],
#           ...,
#           [108, 133, 129],
#           [107, 132, 126],
#           [108, 131, 125]],
#
#          [[107, 117, 116],
#           [105, 115, 114],
#           [105, 115, 114],
#           ...,
#           [104, 129, 123],
#           [104, 127, 121],
#           [102, 125, 119]],
#
#          [[106, 118, 116],
#           [104, 116, 114],
#           [104, 116, 114],
#           ...,
#           [109, 132, 126],
#           [106, 129, 121],
#           [104, 125, 118]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'trailokya_mohan (91).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.00666667, 0.10666667, 0.71666664, 0.70666665]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([7], dtype=int64)>},
#  {'image': <tf.Tensor: shape=(300, 300, 3), dtype=uint8, numpy=
#   array([[[178, 231, 247],
#           [178, 231, 247],
#           [178, 231, 247],
#           ...,
#           [118, 165, 185],
#           [117, 165, 185],
#           [117, 165, 185]],
#
#          [[179, 232, 248],
#           [179, 232, 248],
#           [178, 231, 247],
#           ...,
#           [118, 165, 185],
#           [117, 165, 185],
#           [117, 165, 185]],
#
#          [[179, 232, 248],
#           [179, 232, 248],
#           [179, 232, 248],
#           ...,
#           [118, 165, 185],
#           [117, 165, 185],
#           [117, 165, 185]],
#
#          ...,
#
#          [[109, 121, 109],
#           [108, 120, 108],
#           [108, 120, 108],
#           ...,
#           [108, 138, 128],
#           [108, 138, 128],
#           [108, 138, 128]],
#
#          [[109, 123, 108],
#           [108, 122, 109],
#           [109, 123, 110],
#           ...,
#           [104, 136, 125],
#           [104, 136, 125],
#           [104, 135, 127]],
#
#          [[106, 123, 107],
#           [106, 123, 107],
#           [107, 124, 108],
#           ...,
#           [ 98, 131, 122],
#           [ 98, 131, 122],
#           [ 99, 130, 122]]], dtype=uint8)>,
#   'image/filename': <tf.Tensor: shape=(), dtype=string, numpy=b'trailokya_mohan (92).JPG'>,
#   'bboxes': <tf.Variable 'Variable:0' shape=(1, 4) dtype=float32, numpy=array([[0.02666667, 0.12333333, 0.88666666, 0.6933333 ]], dtype=float32)>,
#   'labels': <tf.Variable 'Variable:0' shape=(1,) dtype=int64, numpy=array([7], dtype=int64)>}]

# %%
# image = tf.data.Dataset.from_tensor_slices([d['image'] for d in dataset])
# bboxes = tf.data.Dataset.from_tensor_slices([d['bboxes'] for d in dataset])
# labels = tf.data.Dataset.from_tensor_slices([d['labels'] for d in dataset])

# ds = tf.data.Dataset.zip((image, bboxes, labels))
# ds = ds.map(lambda x, y, z: {"image": x, "bboxes": y, "labels": z})
